-- %%
DECLARE OR REPLACE v_config_name STRING DEFAULT '${config_name}';
DECLARE OR REPLACE v_layer       STRING DEFAULT '${layer}';
DECLARE OR REPLACE v_system      STRING DEFAULT '${system}';
DECLARE OR REPLACE v_env         STRING DEFAULT '${env}';

-- %%
CALL platform_${env}.utils.proc_run_silver_scd1(
  p_config_name => '${config_name}',
  p_layer       => '${layer}',
  p_system      => '${system}',
  p_env         => '${env}'
);
